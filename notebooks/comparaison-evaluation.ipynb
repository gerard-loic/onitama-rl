# %% [markdown]
# Modèle                                  Acc1    Acc5    Acc10   Acc15
# CNNPlayer-withdropout-weights.weights
# CNNPlayer-withdropout-augmented
# CNNPlayer-withdropout-datalarge
# CNNPlayer-withdropout-datalarge-dropout
# CNNPlayer-v3

# %% [markdown]
# {1: 0.6592, 5: 0.9353, 10: 0.9803, 15: 0.992}
# {1: 0.7066, 5: 0.9599, 10: 0.9901, 15: 0.9957}
# {1: 0.7622, 5: 0.9792, 10: 0.9953, 15: 0.9982}
# {1: 0.6538, 5: 0.9364, 10: 0.9855, 15: 0.9959}
# {1: 0.6406, 5: 0.9333, 10: 0.985, 15: 0.9962}
