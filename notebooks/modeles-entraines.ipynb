# %% [markdown]
# | Version CNNPlayer | Filtres | Couches | Dropout | Données source |
# | ----------------- | ------- | ------- | ------- | -------------- |
# | v1 | 128 | 5 | OUI | panel classique mais augmentées |
# | v1 | 128 | 5 | OUI | panel large |
# | v1 | 128 | 5 | OUI | ??? |
# | v1 | 128 | 5 | OUI | panel classique |
# | v3 | 64 | 2 | OUI | ??? |
