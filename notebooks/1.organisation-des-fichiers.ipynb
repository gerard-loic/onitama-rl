# %% [markdown]
# # Organisation des fichiers / répertoires du projet
#
# | Dossier | Usage |
# | ------- | ----- |
# | data    | Données de parties issues des donnée d'entraînement |
# | notebooks | Notebooks d'exploration et d'explication des démarches |
# | onitama | Les classes et scripts python pour l'environnement, les agents ainsi que les génération des données d'entraînement |
# | saved-models | Networks sauvegardés |
